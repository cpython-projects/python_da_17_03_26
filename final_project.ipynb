# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_06_11_25/blob/main/final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Аналіз продажів мережі магазинів Rossmann
#
# ## Опис датасету
#
# Дані представляють історію продажів мережі магазинів **Rossmann**.
# Rossmann — одна з найбільших роздрібних мереж у Європі, що спеціалізується на продажі товарів повсякденного попиту: косметики, побутової хімії, товарів для дому та здоров’я.
#
# Датасет містить **щоденні показники продажів магазинів**, а також **характеристики самих магазинів**, включаючи інформацію про конкуренцію та маркетингові акції.
#
# Дані представлені у вигляді **двох таблиць**.
#
# ---
#
# ## Таблиця 1. Daily Sales
#
# Містить щоденні показники роботи магазинів.
#
# | Колонка             | Опис                              |
# | ------------------- | --------------------------------- |
# | Store ID            | Ідентифікатор магазину            |
# | Weekday             | День тижня                        |
# | Transaction Date    | Дата                              |
# | Revenue             | Загальна виручка магазину за день |
# | Number of Customers | Кількість клієнтів                |
# | Is Open             | Чи був магазин відкритий          |
# | Has Promo           | Чи діяла промо-акція              |
# | Public Holiday      | Державне свято                    |
# | School Holiday      | Шкільні канікули                  |
#
# ---
#
# ## Таблиця 2. Store Information
#
# Містить характеристики магазинів.
#
# | Колонка           | Опис                                          |
# | ----------------- | --------------------------------------------- |
# | Store ID          | Ідентифікатор магазину                        |
# | Store Category    | Тип магазину                                  |
# | Assortment Level  | Рівень асортименту                            |
# | Competition Dist  | Відстань до найближчого конкурента            |
# | Competition Month | Місяць відкриття конкурента                   |
# | Competition Year  | Рік відкриття конкурента                      |
# | Promo Long Term   | Чи бере магазин участь у довгострокових промо |
# | Promo Week        | Тиждень початку промо                         |
# | Promo Year        | Рік початку промо                             |
# | PromoInterval     | Періоди проведення промо                      |
#
# ---
#
# ## **Базові завдання**
#
# ### Task 1. Сезонність продажів
# Чи існує сезонність продажів?
#
# ### Task 2. Найефективніші магазини
# Визначте магазини з найкращими показниками.
# Необхідно знайти:
# * Top-10 магазинів за виручкою
# * Top-10 магазинів за кількістю клієнтів
# * магазини з найвищим середнім чеком
#
# ### Task 3. Типи магазинів
# Чи впливає тип магазину на результати продажів?
#
# ### Task 4. Продажі за днями тижня
# У які дні тижня магазини працюють найефективніше?
#
# ---
#
# ## **Додаткові завдання**
#
# ### Task 5. Конкуренти
# * Чи падають продажі магазину в перші 3-6 місяців після появи конкурента поруч
# * і чи стабілізуються вони потім?
#
# ### Task 6. Виручка
# * Що сильніше впливає на виручку: акція чи кількість покупців?
# * Чи є зворотна кореляція між відстанню до конкурента та середнім чеком?
#
# ### Task 7. Акції
# Чи для всіх типів магазинів довгострокові акції однаково ефективні? Можливо, для "Luxury" магазинів вони лише шкодять бренду?
#
# ### Task 8. Рекомендації
# На основі проведеного аналізу підготуйте **3–5 бізнес-рекомендацій** для керівництва компанії.
#
# Рекомендації можуть стосуватися, наприклад:
# * оптимального часу для проведення промо-акцій
# * типів магазинів з найкращими результатами
# * сезонних змін у продажах
# * впливу конкуренції

# %% [markdown]
# # Що потрібно здати
#
# ### 1. Jupyter Notebook
#
# Jupyter Notebook повинен містити:
# * Завантаження та очищення всіх джерел даних.
# * Проведення **Exploratory Data Analysis (EDA)**.
# * Створення нових метрик, якщо потрібно.
# * Розрахунок ключових показників продажів.
# * Побудову візуалізацій для дослідження трендів та залежностей.
# * Відповіді мінімум на базові питання.
# * Обґрунтування висновків.
#
# ---
#
# ### 2. Візуалізації
#
# У проєкті повинні бути присутні візуалізації
# Для побудови графіків можна використовувати:
# * seaborn
# * plotly
#
# ---
#
# ### 3. Google Sheets
#
# Необхідно створити **Google Sheets**, у якому будуть представлені підсумкові таблиці з результатами аналізу.
