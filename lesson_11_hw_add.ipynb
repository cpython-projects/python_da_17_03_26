# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_17_03_26/blob/main/lesson_11_hw_add.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Легенда
#
# Датасет містить інформацію про фільми та серіали, доступні на платформі **Netflix**. Кожен рядок таблиці — **один тайтл** (фільм або серіал).
#
# ---
#
# ## Опис стовпців
#
# | Стовпець       | Опис                                       |
# | -------------- | ------------------------------------------ |
# | `show_id`      | Унікальний ідентифікатор тайтлу            |
# | `type`         | Тип контенту: `Movie` або `TV Show`        |
# | `title`        | Назва фільму або серіалу                   |
# | `director`     | Режисер (може бути порожнім)               |
# | `cast`         | Акторський склад (рядок з іменами або NaN) |
# | `country`      | Країна або країни виробництва              |
# | `date_added`   | Дата додавання на Netflix                  |
# | `release_year` | Рік виходу                                 |
# | `rating`       | Віковий рейтинг                            |
# | `duration`     | Тривалість (хвилини або кількість сезонів) |
# | `listed_in`    | Жанр або список жанрів                     |
# | `description`  | Короткий опис                              |

# %% [markdown]
# ### Task 1
#
# Завантажте файл `netflix_titles.csv` (https://raw.githubusercontent.com/cpython-projects/python_da_06_11_25/refs/heads/main/netflix_titles.csv) у DataFrame `df`.

# %% [markdown]
# ### Task 2
#
# Залиште тільки такі стовпці:
#
# * `show_id`
# * `type`
# * `title`
# * `country`
# * `release_year`
# * `rating`
# * `duration`

# %% [markdown]
# ### Task 3
#
# 1. Виведіть кількість рядків і стовпців
# 2. Скільки унікальних значень у стовпці `type`?
# 3. Який мінімальний та максимальний `release_year`?
# 4. Скільки пропущених значень у стовпці `country`?

# %% [markdown]
# ### Task 4
#
# 1. Створіть стовпець `is_movie`, який дорівнює `True`, якщо `type == 'Movie'`
# 2. Перейменуйте стовпець `release_year` на `year`

# %% [markdown]
# ### Task 5
#
# 1. Виведіть всі **фільми**, випущені після 2015 року
# 2. Виведіть всі **серіали** з рейтингом `TV-MA`
# 3. Знайдіть контент, у якого **не вказана країна**
# 4. Виведіть тайтли, у яких у полі `duration` є слово `Season`

# %% [markdown]
# ### Task 6
#
# 1. Відсортуйте дані за `year` у спадному порядку
# 2. Виведіть перші 10 рядків після сортування
# 3. Відсортуйте спочатку за `type`, потім за `year` у зростаючому порядку

# %% [markdown]
# ### Task 7
#
# Чого більше у датасеті: фільмів чи серіалів?
