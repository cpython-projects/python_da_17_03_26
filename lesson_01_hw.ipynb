# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_17_03_26/blob/main/lesson_01_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 1.**
# Напишіть скрипт, який для п’яти цілих чисел (вводяться користувачем з клавіатури), знаходить мінімум, максимум і середнє арифметичне.

# %%
x1 = int(input('number>>'))
x2 = int(input('number>>'))
x3 = int(input('number>>'))
x4 = int(input('number>>'))
x5 = int(input('number>>'))

print(min(x1, x2, x3, x4, x5))
print(max(x1, x2, x3, x4, x5))
print((x1 + x2 + x3 + x4 + x5) / 5)
# Out:
# number>>1
# number>>2
# number>>3
# number>>4
# number>>5
# 1
# 5
# 3.0

# %% [markdown]
# **Task 2.**
# Напишіть скрипт, який повертає результат арифметичних операцій +, -, *, /, // для заданих x і y.

# %%
x, y = int(input('x>>')), int(input('y>>'))

print(f'x + y = {x + y}')
print(f'x - y = {x - y}')
print(f'x * y = {x * y}')
print(f'x / y = {x / y}')
# Out:
# x>>4
# y>>5
# x + y = 9
# x - y = -1
# x * y = 20
# x / y = 0.8

# %% [markdown]
# **Task 3.**
# Напишіть скрипт, який для кола заданого радіуса (вводиться користувачем з клавіатури) знаходить діаметр, довжину кола та площу.

# %%
import math

r = 4
d = 2 * r
# l, I, o, O - bad style
length = 2 * math.pi * r
area = math.pi * r * r

print(f'D={d}')
print(f'L={length:.2f}')
print(f'S={area:.2f}')
# Out:
# D=8
# L=25.13
# S=50.27

# %% [markdown]
# **Task 4.**
# Напишіть скрипт, який розділяє трицифрове ціле число (вводиться користувачем з клавіатури) на окремі цифри. Кожну цифру потрібно вивести в окремому рядку.
# Наприклад, якщо користувач вводить число 987, скрипт має вивести в терміналі:
# 9
# 8
# 7

# %%
x = int(input('number>>'))

print(x // 100) # 123 // 100 -> 1
print(x // 10 % 10) # 123 // 10 -> 12 % 10
print(x % 10)
# Out:
# number>>742
# 7
# 4
# 2

# %% [markdown]
# **Task 5.**
# Деякі інвестиційні консультанти вважають, що в довгостроковій перспективі на фондовому ринку можна очікувати 10% прибутку.
# Припускаючи, що ви починаєте з 1000 доларів і залишаєте ваші гроші інвестованими, обчисліть і виведіть, скільки грошей у вас буде через 10, 20 та 30 років.
# Використайте таку формулу для обчислення суми:
# a = p(1 + r)^n
# де p — початкова інвестована сума (тобто 1000 доларів США),
# r — річна норма прибутку (10%),
# n — кількість років (10, 20 або 30),
# a — сума на рахунку в кінці n-го року.

# %%
n1, n2, n3 = 10, 20, 30

r = 0.1
p = 1000

a1 = p * (1 + r) ** n1
a2 = p * (1 + r) ** n2
a3 = p * (1 + r) ** n3

print(f'{n1} years = ${a1:.2f}')
print(f'{n2} years = ${a2:.2f}')
print(f'{n3} years = ${a3:.2f}')
# Out:
# 10 years = $2593.74
# 20 years = $6727.50
# 30 years = $17449.40
