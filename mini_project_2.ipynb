# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_17_03_26/blob/main/mini_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Проєкт: Аналіз сезонності продажів мережі Walmart
#
# ## Опис проєкту
#
# Компанія Walmart хоче краще зрозуміти сезонні закономірності продажів своїх магазинів.
#
# Вам необхідно провести дослідження історичних даних продажів, виявити сезонні патерни, порівняти поведінку різних магазинів та визначити фактори, які можуть впливати на продажі.
#
# Основна увага повинна бути приділена аналізу сезонності та декомпозиції часових рядів.
#
# ---
#
# ## Дані
#
# ```python
# import pandas as pd
#
# df = pd.read_csv(
#     "https://github.com/cpython-projects/da_1709/raw/refs/heads/main/Walmart.csv"
# )
# ```
#
# Опис полів:
#
# | Поле         | Опис                    |
# | ------------ | ----------------------- |
# | Store        | Ідентифікатор магазину  |
# | Date         | Дата тижня              |
# | Weekly_Sales | Тижневі продажі         |
# | Holiday_Flag | Ознака святкового тижня |
# | Temperature  | Температура             |
# | Fuel_Price   | Ціна палива             |
# | CPI          | Індекс споживчих цін    |
# | Unemployment | Рівень безробіття       |

# %% [markdown]
# ### 1. Чи можна вважати продажі Walmart сезонними?

# %% [markdown]
# ### 2. У які періоди року Walmart отримує найбільший дохід?
#
# Необхідно визначити:
#
# * найсильніші тижні року;
# * найсильніші місяці;
# * можливі причини зростання попиту.

# %% [markdown]
# ### 3. Чи однаково поводяться різні магазини?
#
# Є гіпотеза, що деякі магазини більш залежні від сезонності, ніж інші.
#
# Необхідно дослідити кілька магазинів та визначити:
#
# * чи відрізняються їхні сезонні профілі;
# * які магазини найбільш стабільні;
# * які магазини мають найсильніші сезонні коливання.

# %% [markdown]
# ### 4. Наскільки свята впливають на продажі?
#
# Необхідно оцінити ефективність святкових періодів.
#
# Потрібно з'ясувати:
#
# * чи зростають продажі у святкові тижні;
# * наскільки велика різниця між святковими та звичайними періодами;
# * чи однаково реагують різні магазини.

# %% [markdown]
# ### 5. Які приховані компоненти містить часовий ряд продажів?
#
# Використайте STL-декомпозицію та визначте:
#
# * довгостроковий тренд;
# * сезонну компоненту;
# * випадкові коливання та можливі аномалії.

# %% [markdown]
# ### 6. Чи впливають зовнішні фактори на продажі?
#
# Є гіпотеза, що на попит можуть впливати:
#
# * температура;
# * ціни на паливо;
# * інфляція (CPI);
# * рівень безробіття.
#
# Необхідно оцінити, чи існує зв'язок між цими показниками та продажами.

# %% [markdown]
# ### 7. Які магазини є найбільш цінними для компанії?
#
# Сформуйте рейтинг магазинів та визначте:
#
# * лідерів за обсягом продажів;
# * найбільш стабільні магазини;
# * магазини з найсильнішою сезонністю.

# %% [markdown]
# ## Фінальна рекомендація
#
# Наприкінці дослідження підготуйте короткий звіт
