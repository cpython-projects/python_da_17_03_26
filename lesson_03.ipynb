# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_17_03_26/blob/main/lesson_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = int(input('T>>'))

if t < -10:
  print('It is cold!')

print('Have a nice day!')
# Out:
# T>>-20
# It is cold!
# Have a nice day!

# %%
t = int(input('T>>'))

if t < -10:
  name = input('name>>')
  print(f'{name}, it is cold!')
else:
  print('It is normal')

print('Have a nice day!')
# Out:
# T>>-20
# name>>Oleh
# Oleh, it is cold!
# Have a nice day!

# %%
t = int(input('T>>'))

if t < -20:
  print('It is very cold')
else:
  if t < -10:
    print('It is cold')
  else:
    if t < 10:
      print('It is normal')
    else:
      if t < 30:
        print('It is warm')
      else:
        print('It is hot')

# %%
t = int(input('T>>'))

if t < -20:
    print('It is very cold')
elif t < -10:
    print('It is cold')
elif t < 10:
    print('It is normal')
elif t < 30:
    print('It is warm')
else:
    print('It is hot')

print('Have a nice day')

# %%
points = int(input('points>>'))

if points < 0 or points > 100:
    print('Invalid points')
elif points < 60:
    print('F')
elif points < 66:
    print('E')
elif points < 71:
    print('D')
elif points < 80:
    print('C')
elif points < 90:
    print('B')
else:
    print('A')

# %%
x = 6

if x % 2:
    print('Odd')
else:
    print('Even')


name = input('Enter your name: ')

if name:
    print(name.upper())
else:
    print('Guest User')

# %%
x = 6

if x % 2:
    res = 'Odd'
else:
    res = 'Even'

print(res)

res = 'Odd' if x % 2 else 'Even'
print(res)

# %%
# mean, median, moda

# %%
(6 + 8 + 8 + 6 + 100) / 5
# Out:
# 25.6

# %%
6, 8, 1, 2, 3, 7, 9, 100

1, 2, 3, 6, 7, 8, 9, 100

k = 8

mid = 6, 7
mid = 6.5

# %%
1, 1, 1, 1, 3, 4, 5, 6, 6, 6

1 = 4
3 - 1
4 - 1
5 - 1
6 - 3
