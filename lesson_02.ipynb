# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_17_03_26/blob/main/lesson_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # id

# %%
x = 5
print(x, id(x))
x = x + 1
print(x, id(x))
# Out:
# 5 11645480
# 6 11645512

# %%
x = 5
print(x)
x = 'Hello'
print(x)
# Out:
# 5
# Hello

# %%
x = [1, 2, 3, 4]
y = x

y[0] = 100

print(x)
print(y)
# Out:
# [100, 2, 3, 4]
# [100, 2, 3, 4]

# %% [markdown]
# # type

# %%
# numbers: int, float, complex, bool
x_int = 123
x_float = 345.56
x_complex = (-8) ** 0.5
x_bool = True

print(x_int)
print(x_float)
print(x_complex)
print(x_bool)
# Out:
# 123
# 345.56
# (1.7319121124709868e-16+2.8284271247461903j)
# True

# %%
# sequences

x = 'asdfghjklyutut'
x = [78, 56, 78]
x = (78, 89, 45)
x = {7, 8, 9}
x = {1: 'one', 2: 'two'}

# %%
# x32, x64
# int - unlimited
print(x ** 100)
# Out:
# ...

# %%
x = 1_000_000
print(x)
# Out:
# 1000000

# %%
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
0.1 + 0.1 + 0.1
# Out:
# 0.30000000000000004

# %%
5 > 6
# Out:
# False

# %%
5 >= 6
# Out:
# False

# %%
5 < 6
# Out:
# True

# %%
5 <= 6
# Out:
# True

# %%
5 == 6
# Out:
# False

# %%
5 != 6
# Out:
# True

# %%
0.1 + 0.1 + 0.1 == 0.3
# Out:
# False

# %%
import math

# is = True/False
x = 0.1 + 0.1 + 0.1
y = 0.3
math.isclose(x, y) # 10^-9 = 0.0000...
# Out:
# True

# %%
from decimal import Decimal

x = Decimal('0.1')
y = Decimal('0.3')

x + x + x == y
# Out:
# True

# %%
x = 10.
print(x)
# Out:
# 10.0

# %%
x = .001
print(x)
# Out:
# 0.001

# %%
x = 12e-3
print(x)
# Out:
# 0.012

# %%
x = 12.04
print(round(x))
print(round(x, 1))
# Out:
# 12
# 12.0

# %%
x = 12.5
print(round(x))
x = 13.5
print(round(x))
# Out:
# 12
# 14

# %%
from decimal import Decimal, ROUND_UP, ROUND_DOWN, ROUND_05UP

x = Decimal('4.53')
print(x.quantize(Decimal('0.1'), rounding=ROUND_05UP))
# Out:
# 4.6

# %%
box = 4
oranges = 17

print(math.ceil(oranges / box))
print(math.floor(oranges / box))
# Out:
# 5
# 4

# %%
x = True # 1
y = False # 0

# %%
x = Decimal(0.1)
x
# Out:
# Decimal('0.1000000000000000055511151231257827021181583404541015625')

# %%
price = 100

(price > 500) * 5
# Out:
# 0
