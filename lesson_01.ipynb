# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_17_03_26/blob/main/lesson_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(2, 3, 4, 5, 'Hello world')
# Out:
# 2 3 4 5 Hello world

# %%
print(2, 3, 4, 5, 'Hello world', sep='***')
# Out:
# 2***3***4***5***Hello world

# %%
print(2, 3, 4, 5, 'Hello world', sep='\n')
# Out:
# 2
# 3
# 4
# 5
# Hello world

# %%
number = input()
# Out:
# 1234

# %%
a = int(input('number>>'))
b = int(input('number>>'))
# Out:
# number>>4
# number>>6

# %%
a + b
# Out:
# 10

# %%
a = 5
b = 2

print(a + b)
print(a - b)
print(a * b)
# Out:
# 7
# 3
# 10

# %%
print(a / b)
# Out:
# 2.5

# %%
print(5 // 2)
# Out:
# 2

# %%
print(-5 // 2)
# Out:
# -3

# %%
print(5 % 2)
# Out:
# 1

# %%
x = 100
# 1% - 0.01

y = x * 0.2
print(x, y)
# Out:
# 100 20.0

# %%
x = 100
# 1% - 0.01

y = x * 1.2
print(x, y)
# Out:
# 100 120.0

# %%
2 ** 3
# Out:
# 8

# %%
2 ** 0.5
# Out:
# 1.4142135623730951

# %%
(-8) ** 0.5
# Out:
# (1.7319121124709868e-16+2.8284271247461903j)

# %%
min(1, 2, 3, 4, 5)
# Out:
# 1

# %%
max(2, 3, 4, 5, 6)
# Out:
# 6

# %%
(1 + 4 + 6) / 3
# Out:
# 3.6666666666666665
