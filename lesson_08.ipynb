# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_17_03_26/blob/main/lesson_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Що таке словник (dict)**
#
# **dict** — це **впорядкована (з Python 3.7+), змінювана структура даних**, яка зберігає пари **ключ → значення**.
#
# Використовується для зберігання:
#
# * даних з JSON
# * конфігурацій
# * параметрів моделей
# * результатів API
# * статистики
# * рахунків, замовлень
# * словників частот
# * структурованої інформації
#
# ---
#
# ## **Три ключові властивості**
#
# ### **1. Впорядкованість (ordered)**
#
# * Елементи зберігаються у порядку додавання.
# * Це дозволяє ітеруватись передбачувано.
#
# ### **2. Змінюваність (mutable)**
#
# * Можна додавати, видаляти, змінювати елементи без створення нового dict.
#
# ### **3. Ключі — унікальні**
#
# * Ключі не можуть повторюватись.
# * Якщо додати ключ повторно → значення перезапишеться.

# %%
x = {1: 'one', 2: ['two', 'два']}
print(x)
# Out:
# {1: 'one', 2: ['two', 'два']}

# %%
hash('Hello')
# Out:
# 2971239535810428789

# %%
hash('Hella')
# Out:
# 4266502004284530623

# %%
hash([9, 8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_661/4057542898.py in <cell line: 0>()
# ----> 1 hash([9, 8])
#
# TypeError: unhashable type: 'list'

# %%
hash((8, 7))
# Out:
# 8874407394921044968

# %%
x = [1, 2, 3]
y = (x, 'Hello')
print(y)
# Out:
# ([1, 2, 3], 'Hello')

# %%
hash(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_661/182665142.py in <cell line: 0>()
# ----> 1 hash(y)
#
# TypeError: unhashable type: 'list'

# %%
x = {(6, 7): 1}

# %%
x = {1: 'one', 2: 'two', 1: 'bir', 'one': 1}
x[10]
# Out:
# 'bir'

# %% [markdown]
# # **2. Створення словників**
#
# ```python
# x = {"name": "Oleh", "age": 30}
# y = dict(city="Kyiv", rank=1)
#
# print(x)
# print(y)
# ```
#
# Порожній словник:
#
# ```python
# x = {}
# y = dict()
# ```
#
# Доступ до значення:
#
# ```python
# person = {"name": "Oleh", "age": 30}
# print(person["name"])
# ```

# %% [markdown]
# # **3. Операції зі словниками**

# %% [markdown]
# **Додавання / зміна елементів**

# %%
x = {'one': 1, 'two': 2}
x
# Out:
# {'one': 1, 'two': 2}

# %%
x['one']
# Out:
# 1

# %%
x['two']
# Out:
# 2

# %%
x['three']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_661/3371889263.py in <cell line: 0>()
# ----> 1 x['three']
#
# KeyError: 'three'

# %%
x['three'] = 3
x
# Out:
# {'one': 1, 'two': 2, 'three': 3}

# %%
x['one'] = 'bir'
x
# Out:
# {'one': 'bir', 'two': 2, 'three': 3}

# %%
del x['one']
x
# Out:
# {'two': 2, 'three': 3}

# %% [markdown]
# **Перевірка ключа**

# %%
'one' in x
# Out:
# False

# %% [markdown]
# **Видалення**

# %%
del x['one']
x
# Out:
# {'two': 2, 'three': 3}

# %% [markdown]
# **Перебір елементів**

# %%
for key in x:
  print(key, x[key])
# Out:
# two 2
# three 3

# %% [markdown]
# **Копіювання**

# %%
y = x.copy()

y['four'] = 4
print(x)
print(y)
# Out:
# {'two': 2, 'three': 3}
# {'two': 2, 'three': 3, 'four': 4}

# %% [markdown]
# # **4. Основні методи словників**

# %% [markdown]
# ## `.get()`
#
# Безпечне отримання значення (не викликає помилки)

# %%
x
# Out:
# {'two': 2, 'three': 3}

# %%
x.get('two')
# Out:
# 2

# %%
x['four']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3098953889.py in <cell line: 0>()
# ----> 1 x['four']
#
# KeyError: 'four'

# %%
res = x.get('four', 'Unknown')
print(res)
# Out:
# Unknown

# %% [markdown]
# ## `.keys(), .values(), .items()`

# %%
x = {1: 'one', 2: 'two', 3: 'three'}

# %%
x.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
x.values()
# Out:
# dict_values(['one', 'two', 'three'])

# %%
x.items()
# Out:
# dict_items([(1, 'one'), (2, 'two'), (3, 'three')])

# %%
for key, value in x.items():
  print(key, value)
# Out:
# 1 one
# 2 two
# 3 three

# %% [markdown]
# ## `.pop()`

# %%
x
# Out:
# {'two': 2, 'three': 3}

# %%
x.pop('two')
# Out:
# 2

# %%
x
# Out:
# {'three': 3}

# %% [markdown]
# # **5. Порівняння словників**
#
# ### Порівнюються за вмістом, а не за порядком:
#
# ```python
# {"a": 1, "b": 2} == {"b": 2, "a": 1}   # True
# ```
#
# Ключі — унікальні:
#
# ```python
# x = {"a": 1, "a": 2}
# print(x)    # {'a': 2}
# ```

# %%
x = [1, 1, 1, 1, 2, 2, 3, 3, 3, 4, 5, 6, 7, 8]

# %%
from collections import Counter

res = Counter(x)
for key, value in res.items():
  print(key, value)
# Out:
# 1 4
# 2 2
# 3 3
# 4 1
# 5 1
# 6 1
# 7 1
# 8 1

# %%
res.most_common(2)
# Out:
# [(1, 4), (3, 3)]

# %%
from collections import defaultdict


# text = "Python is great and Python is easy and data is powerful".lower()
text = 'aaaabbbbbcc'

counter = defaultdict(int)

for letter in text:
    counter[letter] = counter[letter] + 1

print(counter)
# Out:
# defaultdict(<class 'int'>, {'a': 4, 'b': 5, 'c': 2})

# %% [markdown]
# # **6. Типові помилки**
#
# ❌ доступ до неіснуючого ключа
#
# ```python
# user["email"]  # KeyError
# ```
#
# ✔ правильно
#
# ```python
# user.get("email")
# ```
#
# ❌ ключ — незмінний тип (список не можна)
#
# ```python
# x = {[1,2]: "value"}   # Error
# ```
#
# ✔ можна використовувати рядки, числа, кортежі:
#
# ```python
# x = {(1,2): "ok"}
# ```

# %% [markdown]
# # **7. Задачі**

# %%
text = "Python is great and Python is easy and data is powerful".lower()
buff = []
for letter in text:
  if letter not in buff:
    print(letter, text.count(letter))
    buff.append(letter)
# Out:
# p 3
# y 3
# t 4
# h 2
# o 3
# n 4
#   10
# i 3
# s 4
# g 1
# r 2
# e 3
# a 6
# d 3
# w 1
# f 1
# u 1
# l 1

# %%
# text = "Python is great and Python is easy and data is powerful".lower()
text = 'aaaabbbbbcc'

counter = {}

for letter in text:
    if letter in counter:
        counter[letter] += 1
    else:
        counter[letter] = 1

print(counter)
# Out:
# {'a': 4, 'b': 5, 'c': 2}

# %% [markdown]
# ## **1. Частота слів у тексті (аналітика відгуків)**
#
# Є текст відгуку:
#
# ```python
# text = "Python is great and Python is easy and data is powerful"
# ```
#
# ### **Завдання:**
#
# 1. Перетворити текст у список слів.
# 2. Порахувати частоту появи кожного слова (dict).
# 3. Вивести слово, яке зустрічається найчастіше.
# 4. Вивести всі слова, які зустрічаються лише один раз.

# %%
import string
text = "Python is great and Python is easy and data is powerful".lower()
for item in string.punctuation:
  text = text.replace(item, ' ')
words = text.split()
words
# Out:
# ['python',
#  'is',
#  'great',
#  'and',
#  'python',
#  'is',
#  'easy',
#  'and',
#  'data',
#  'is',
#  'powerful']

# %%
counter = {}
for key in words:
  if key in counter:
    counter[key] += 1
  else:
    counter[key] = 1

counter
# Out:
# {'python': 2,
#  'is': 3,
#  'great': 1,
#  'and': 2,
#  'easy': 1,
#  'data': 1,
#  'powerful': 1}

# %%
counter['is']
# Out:
# 3

# %%
counter['is1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_661/1145802165.py in <cell line: 0>()
# ----> 1 counter['is1']
#
# KeyError: 'is1'

# %%
counter.get('is')
# Out:
# 3

# %%
print(counter.get('is1'))
# Out:
# None

# %%
counter.get('is1', 0)
# Out:
# 0

# %%
max(counter, key=counter.get)
# Out:
# 'is'

# %%
for key in counter:
  if counter[key] == 1:
    print(key)
# Out:
# great
# easy
# data
# powerful

# %% [markdown]
# ## **2. Статистика продажів інтернет-магазину**
#
# У вас є список замовлень за день:
#
# ```python
# orders = [
#     {"id": 1, "user": "oleg", "amount": 120},
#     {"id": 2, "user": "anna", "amount": 300},
#     {"id": 3, "user": "oleg", "amount": 80},
#     {"id": 4, "user": "ivan", "amount": 50},
#     {"id": 5, "user": "anna", "amount": 220},
# ]
# ```
#
# ### **Завдання:**
#
# 1. Порахувати загальну суму продажів.
# 2. Знайти користувача з найбільшою сумою покупок.
# 3. Створити словник виду:
#
# ```python
# {
#   "oleg": 200,
#   "anna": 520,
#   "ivan": 50
# }
# ```
#
# 4. Вивести середню суму одного замовлення.

# %%
orders = [
    {"id": 1, "user": "oleg", "amount": 120},
    {"id": 2, "user": "anna", "amount": 300},
    {"id": 3, "user": "oleg", "amount": 80},
    {"id": 4, "user": "ivan", "amount": 50},
    {"id": 5, "user": "anna", "amount": 220},
]

total = 0
for order in orders:
  total += order['amount']

print(total)

res  =sum(order['amount'] for order in orders)
print(res)
# Out:
# 770
# 770

# %%
users = {}
for order in orders:
  if order['user'] in users:
    users[order['user']] += order['amount']
  else:
    users[order['user']] = order['amount']

print(users)
# Out:
# {'oleg': 200, 'anna': 520, 'ivan': 50}

# %%
max(users, key=users.get)
# Out:
# 'anna'

# %%
total / len(orders)
# Out:
# 154.0

# %% [markdown]
# ## **3. Парсинг логів сервера**
#
# ```python
# logs = [
#     "ERROR 500 Database failed",
#     "WARN 300 Slow response",
#     "INFO 200 OK",
#     "ERROR 404 Not found",
#     "INFO 200 OK",
# ]
# ```
#
# ### **Завдання:**
#
# 1. Порахувати, скільки разів зустрічається кожен тип: `ERROR`, `WARN`, `INFO`.
# 2. Зробити словник:
#
# ```python
# {
#   "ERROR": 2,
#   "WARN": 1,
#   "INFO": 2
# }
# ```
#
# 3. Знайти всі записи статусу `200`.
# 4. Зібрати список лише повідомлень (після коду):
#
# ```
# "Database failed"
# "Slow response"
# "OK"
# "Not found"
# "OK"
# ```

# %% [markdown]
# ## **4. Нормалізація цін з різних джерел**
#
# ```python
# raw_prices = ["$120", " 130 USD", "140$", "150usd", "\n160  "]
# ```
#
# ### **Завдання:**
#
# 1. Перетворити всі рядки до чисел типу `int`.
# 2. Порахувати середнє, мінімум і максимум.
# 3. Створити список цін у форматі:
#
# ```
# "120 USD"
# "130 USD"
# "140 USD"
# ...
# ```
#
# 4. Порахувати кількість цін > 140.

# %% [markdown]
# ## **5. Категоризація покупців за віком**
#
# Є список:
#
# ```python
# ages = [12, 25, 17, 40, 33, 60, 15, 22]
# ```
#
# ### **Завдання:**
#
# 1. Створити словник:
#
# ```python
# {
#   "kids": [],
#   "adults": [],
#   "seniors": []
# }
# ```
#
# Де:
#
# * kids < 18
# * adults 18–50
# * seniors > 50
#
# 2. Порахувати кількість людей у кожній групі.
# 3. Вивести групу з найбільшою кількістю людей.

# %%
x = 1, 2, 3, 4, 5, 6
print(x)
print(type(x))
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>

# %%
x = [1, 2, 3]

a, b, c = x
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
a, b, c = 'Pyt'
print(a)
print(b)
print(c)
# Out:
# P
# y
# t

# %%
x = [1, 2, 3, 4, 5, 6, 7]

a, b, c = x
print(a)
print(b)
print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_661/3036975411.py in <cell line: 0>()
#       1 x = [1, 2, 3, 4, 5, 6, 7]
#       2
# ----> 3 a, b, c = x
#       4 print(a)
#       5 print(b)
#
# ValueError: too many values to unpack (expected 3)

# %%
x = [1, 2, 3, 4, 5, 6, 7]

*a, b, c = x
print(a)
print(b)
print(c)
# Out:
# [1, 2, 3, 4, 5]
# 6
# 7

# %%
a, *b, c = x
print(a)
print(b)
print(c)
# Out:
# 1
# [2, 3, 4, 5, 6]
# 7

# %%
a, b, *c = x
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# [3, 4, 5, 6, 7]

# %%
*a, *b, c = x
print(a)
print(b)
print(c)
# Out:
#   File "/tmp/ipykernel_661/1203141786.py", line 1
#     *a, *b, c = x
#     ^
# SyntaxError: multiple starred expressions in assignment

# %%
x = [1, 2]
*a, b, c = x
print(a)
print(b)
print(c)
# Out:
# []
# 1
# 2

# %%
x = [1, 2, 2]
*a, b, c = x
print(a)
print(b)
print(c)
# Out:
# [1]
# 2
# 2

# %%
data = [
    '1 Bob Simson 19.58$ decorations',
    '2 Mary 66.7$ food',
    '3 Mary 98.91$ toys',
    '4 Aleksa 72.29$ drinks',
    '5 Maria Simson 84.48$ food',
    '6 Aleksa 100.41$ accessories',
    '7 Mary 19.9$ accessories',
    '8 Bob Simson 83.88$ drinks',
    '9 Bob Simson 58.21$ instruments',
    '10 Maria Simson 20.61$ accessories',
]

# %%
expenses_by_users = {}

for line in data:
  line = line.split()
  _, *name, amount, _ = line
  name = ' '.join(name)
  amount = float(amount.replace('$', ''))

  if name in expenses_by_users:
    expenses_by_users[name] += amount
  else:
    expenses_by_users[name] = amount

print(*expenses_by_users.items(), sep='\n')
# Out:
# ('Bob Simson', 161.67)
# ('Mary', 185.51000000000002)
# ('Aleksa', 172.7)
# ('Maria Simson', 105.09)

# %%
expenses = {}

for line in data:
  line = line.split()
  amount = float(line[-2].replace('$', ''))
  category = line[-1].lower()

  if category in expenses:
    expenses[category] += amount
  else:
    expenses[category] = amount

print(*expenses.items(), sep='\n')
# Out:
# ('decorations', 19.58)
# ('food', 151.18)
# ('toys', 98.91)
# ('drinks', 156.17000000000002)
# ('accessories', 140.92000000000002)
# ('instruments', 58.21)

# %%
total = 0
for line in data:
  line = line.split()
  amount = float(line[-2].replace('$', ''))
  total += amount

print(f'{total:.2f}$')
# Out:
# 624.97$

# %%
x = [1, 2, 3, 4]
y = ['one', 'two', 'three', 'four']

for i in range(min(len(x), len(y))):
  print(x[i], y[i])
# Out:
# 1 one
# 2 two
# 3 three
# 4 four

# %%
x = [1, 2, 3, 4]
y = ['one', 'two', 'three', 'four']

for item_x, item_y in zip(x, y):
  print(item_x, item_y)
# Out:
# 1 one
# 2 two
# 3 three
# 4 four

# %%
res = dict(zip(y, x))
print(res)
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4}
