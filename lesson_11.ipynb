# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_17_03_26/blob/main/lesson_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
x = ['one', 'two', 'three', 'four']
s = pd.Series(x)
s
# Out:
# 0      one
# 1      two
# 2    three
# 3     four
# dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
x = {'one': 1, 'two': 2, 'three': 3, 'four': 4}
s = pd.Series(x)
s
# Out:
# one      1
# two      2
# three    3
# four     4
# dtype: int64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv', encoding='utf-8', delimiter=',')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
n_rows, n_cols = df.shape
print(n_rows, n_cols)
# Out:
# 891 12

# %%
df.columns.to_list()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.rename(
    columns={'Sex': 'Gender', 'PassengerId': 'id'}, inplace=True
)

# %%
df
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
df['Name'] = df['Name'].str.upper()

# %%
df
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            BRAUND, MR. OWEN HARRIS
# 1      2         1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2      3         1       3                             HEIKKINEN, MISS. LAINA
# 3      4         1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4      5         0       3                           ALLEN, MR. WILLIAM HENRY
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              MONTVILA, REV. JUOZAS
# 887  888         1       1                       GRAHAM, MISS. MARGARET EDITH
# 888  889         0       3           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889  890         1       1                              BEHR, MR. KARL HOWELL
# 890  891         0       3                                DOOLEY, MR. PATRICK
#
# ...

# %%
def age_category(age):
  if age > 18:
    return 'Adult'
  return 'Child'

# %%
df['is_adult'] = df.Age.apply(age_category)

# %%
df
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            BRAUND, MR. OWEN HARRIS
# 1      2         1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2      3         1       3                             HEIKKINEN, MISS. LAINA
# 3      4         1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4      5         0       3                           ALLEN, MR. WILLIAM HENRY
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              MONTVILA, REV. JUOZAS
# 887  888         1       1                       GRAHAM, MISS. MARGARET EDITH
# 888  889         0       3           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889  890         1       1                              BEHR, MR. KARL HOWELL
# 890  891         0       3                                DOOLEY, MR. PATRICK
#
# ...

# %%
df.columns.to_list()
# Out:
# ['id',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Gender',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'is_adult']

# %%
df_filtered = df[['Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp', 'Parch']]

# %%
df_filtered
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            BRAUND, MR. OWEN HARRIS
# 1           1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2           1       3                             HEIKKINEN, MISS. LAINA
# 3           1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4           0       3                           ALLEN, MR. WILLIAM HENRY
# ..        ...     ...                                                ...
# 886         0       2                              MONTVILA, REV. JUOZAS
# 887         1       1                       GRAHAM, MISS. MARGARET EDITH
# 888         0       3           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889         1       1                              BEHR, MR. KARL HOWELL
# 890         0       3                                DOOLEY, MR. PATRICK
#
#      Gender   Age  SibSp  Parch
# 0      male  22.0      1      0
# ...

# %%
df['is_adult'] = df['Age'] > 18

# %%
df_female = df[df['Gender'] == 'female']

# %%
df_female
# Out:
#       id  Survived  Pclass                                               Name  \
# 1      2         1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2      3         1       3                             HEIKKINEN, MISS. LAINA
# 3      4         1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 8      9         1       3  JOHNSON, MRS. OSCAR W (ELISABETH VILHELMINA BERG)
# 9     10         1       2                NASSER, MRS. NICHOLAS (ADELE ACHEM)
# ..   ...       ...     ...                                                ...
# 880  881         1       2       SHELLEY, MRS. WILLIAM (IMANITA PARRISH HALL)
# 882  883         0       3                       DAHLBERG, MISS. GERDA ULRIKA
# 885  886         0       3               RICE, MRS. WILLIAM (MARGARET NORTON)
# 887  888         1       1                       GRAHAM, MISS. MARGARET EDITH
# 888  889         0       3           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
#
# ...

# %%
df_male = df[df['Gender'] == 'male']

# %%
df_male
# Out:
#       id  Survived  Pclass                            Name Gender   Age  \
# 0      1         0       3         BRAUND, MR. OWEN HARRIS   male  22.0
# 4      5         0       3        ALLEN, MR. WILLIAM HENRY   male  35.0
# 5      6         0       3                MORAN, MR. JAMES   male   NaN
# 6      7         0       1         MCCARTHY, MR. TIMOTHY J   male  54.0
# 7      8         0       3  PALSSON, MASTER. GOSTA LEONARD   male   2.0
# ..   ...       ...     ...                             ...    ...   ...
# 883  884         0       2   BANFIELD, MR. FREDERICK JAMES   male  28.0
# 884  885         0       3          SUTEHALL, MR. HENRY JR   male  25.0
# 886  887         0       2           MONTVILA, REV. JUOZAS   male  27.0
# 889  890         1       1           BEHR, MR. KARL HOWELL   male  26.0
# 890  891         0       3             DOOLEY, MR. PATRICK   male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  is_adult
# ...

# %%
df.Age.hist(bins=50)
# Out:
# <Axes: >

# %%
df_male_older_20 = df[(df['Gender'] == 'male') & (df['Age'] > 20)] # and = &, or = |, not = ~, xor = ^

# %%
df_male_older_20
# Out:
#       id  Survived  Pclass                           Name Gender   Age  SibSp  \
# 0      1         0       3        BRAUND, MR. OWEN HARRIS   male  22.0      1
# 4      5         0       3       ALLEN, MR. WILLIAM HENRY   male  35.0      0
# 6      7         0       1        MCCARTHY, MR. TIMOTHY J   male  54.0      0
# 13    14         0       3    ANDERSSON, MR. ANDERS JOHAN   male  39.0      1
# 20    21         0       2           FYNNEY, MR. JOSEPH J   male  35.0      0
# ..   ...       ...     ...                            ...    ...   ...    ...
# 883  884         0       2  BANFIELD, MR. FREDERICK JAMES   male  28.0      0
# 884  885         0       3         SUTEHALL, MR. HENRY JR   male  25.0      0
# 886  887         0       2          MONTVILA, REV. JUOZAS   male  27.0      0
# 889  890         1       1          BEHR, MR. KARL HOWELL   male  26.0      0
# 890  891         0       3            DOOLEY, MR. PATRICK   male  32.0      0
#
# ...

# %%
df[~(df['Gender'] == 'male')]
# Out:
#       id  Survived  Pclass                                               Name  \
# 1      2         1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2      3         1       3                             HEIKKINEN, MISS. LAINA
# 3      4         1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 8      9         1       3  JOHNSON, MRS. OSCAR W (ELISABETH VILHELMINA BERG)
# 9     10         1       2                NASSER, MRS. NICHOLAS (ADELE ACHEM)
# ..   ...       ...     ...                                                ...
# 880  881         1       2       SHELLEY, MRS. WILLIAM (IMANITA PARRISH HALL)
# 882  883         0       3                       DAHLBERG, MISS. GERDA ULRIKA
# 885  886         0       3               RICE, MRS. WILLIAM (MARGARET NORTON)
# 887  888         1       1                       GRAHAM, MISS. MARGARET EDITH
# 888  889         0       3           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
#
# ...

# %%
df
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            BRAUND, MR. OWEN HARRIS
# 1      2         1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2      3         1       3                             HEIKKINEN, MISS. LAINA
# 3      4         1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4      5         0       3                           ALLEN, MR. WILLIAM HENRY
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              MONTVILA, REV. JUOZAS
# 887  888         1       1                       GRAHAM, MISS. MARGARET EDITH
# 888  889         0       3           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889  890         1       1                              BEHR, MR. KARL HOWELL
# 890  891         0       3                                DOOLEY, MR. PATRICK
#
# ...

# %%
df.Gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Gender.nunique()
# Out:
# 2

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df.Age.min()
# Out:
# 0.42

# %%
df.Age.max()
# Out:
# 80.0

# %%
df.Age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
df.Age.median()
# Out:
# 28.0

# %%
df.Age.std()
# Out:
# 14.526497332334044

# %%
df.Age.hist(bins=50)
# Out:
# <Axes: >

# %%
df.Age.quantile(0.25)
# Out:
# np.float64(20.125)

# %%
df.Age.quantile(0.5)
# Out:
# np.float64(28.0)

# %%
df.Age.quantile(0.75)
# Out:
# np.float64(38.0)

# %%
q_99 = df.Age.quantile(0.99)
q_99
# Out:
# np.float64(65.87)

# %%
df_new = df[df['Age'] < q_99]

# %%
df_new.shape
# Out:
# (706, 13)

# %%
df_new['Age'].hist(bins=50)
# Out:
# <Axes: >
